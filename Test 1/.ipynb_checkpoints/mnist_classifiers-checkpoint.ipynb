# %%
import sys
import os
sys.path.append(os.path.abspath('../src'))  # путь к папке src

from classifier import MnistClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       2 import os
#       3 sys.path.append(os.path.abspath('../src'))  # путь к папке src
# ----> 5 from classifier import MnistClassifier
#
# ModuleNotFoundError: No module named 'classifier'
